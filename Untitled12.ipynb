# %% [markdown]
# <a href="https://colab.research.google.com/github/MbuyiseloNtando/Stock-prices/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import quandl

# %%
df = quandl.get('WIKI/GOOGL')

# %%
df.head()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# 2004-08-25          1.0  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# ...

# %%
df = df[['Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume']]  #DataFrame with columns of interest

# %%
df.head()
# Out:
#             Adj. Close    HL_PCT  PCT_change  Adj. Volume      label
# Date
# 2004-08-19   50.322842  3.712563    0.324968   44659000.0  69.078238
# 2004-08-20   54.322689  0.710922    7.227007   22834300.0  67.839414
# 2004-08-23   54.869377  3.729433   -1.227880   18256100.0  68.912727
# 2004-08-24   52.597363  6.417469   -5.726357   15247300.0  70.668146
# 2004-08-25   53.164113  1.886792    1.183658    9188600.0  71.219849

# %%
df['HL_PCT'] = (df['Adj. High'] - df['Adj. Close']) / df['Adj. Close'] * 100.0  #High and Low percent change

# %%
df['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0  #Percent change

# %%
df = df[['Adj. Close', 'HL_PCT', 'PCT_change', 'Adj. Volume']]

# %%
df.head()
# Out:
#             Adj. Close    HL_PCT  PCT_change  Adj. Volume
# Date
# 2004-08-19   50.322842  3.712563    0.324968   44659000.0
# 2004-08-20   54.322689  0.710922    7.227007   22834300.0
# 2004-08-23   54.869377  3.729433   -1.227880   18256100.0
# 2004-08-24   52.597363  6.417469   -5.726357   15247300.0
# 2004-08-25   53.164113  1.886792    1.183658    9188600.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3424 entries, 2004-08-19 to 2018-03-27
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Adj. Close   3424 non-null   float64
#  1   HL_PCT       3424 non-null   float64
#  2   PCT_change   3424 non-null   float64
#  3   Adj. Volume  3424 non-null   float64
# dtypes: float64(4)
# memory usage: 133.8 KB

# %%
forecast_col = 'Adj. Close'

# %%
df.isnull( ).sum()
# Out:
# Adj. Close     0
# HL_PCT         0
# PCT_change     0
# Adj. Volume    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import math

# %%
forecast_out = int(math.ceil(0.01* len(df)))   #Number of days out using 10% of the DataFrame (using data from 10 days ago)

# %%
df['label'] = df[forecast_col].shift(-forecast_out)

# %%
df.head()
# Out:
#             Adj. Close    HL_PCT  PCT_change  Adj. Volume      label
# Date
# 2004-08-19   50.322842  3.712563    0.324968   44659000.0  69.078238
# 2004-08-20   54.322689  0.710922    7.227007   22834300.0  67.839414
# 2004-08-23   54.869377  3.729433   -1.227880   18256100.0  68.912727
# 2004-08-24   52.597363  6.417469   -5.726357   15247300.0  70.668146
# 2004-08-25   53.164113  1.886792    1.183658    9188600.0  71.219849

# %%
df.isnull().sum()
# Out:
# Adj. Close      0
# HL_PCT          0
# PCT_change      0
# Adj. Volume     0
# label          35
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
import numpy as np
from sklearn import preprocessing, train_test_split, svm
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-23b7a64788a7> in <cell line: 2>()
#       1 import numpy as np
# ----> 2 from sklearn import preprocessing, train_test_split, svm
#       3 from sklearn.linear_model import LinearRegression
#
# ImportError: cannot import name 'train_test_split' from 'sklearn' (/usr/local/lib/python3.10/dist-packages/sklearn/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
 X = np.array(df.drop(['label'], axis=1))  #Features
 y = np.array(df['label'])  #Labels

# %%
X = preprocessing.scale(X)    #Scaling features

# %%
df.isnull().sum()
# Out:
# Adj. Close     0
# HL_PCT         0
# PCT_change     0
# Adj. Volume    0
# label          0
# dtype: int64

# %%
len(X), len(y)
# Out:
# (3389, 3389)

# %%
y = preprocessing.scale(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-19ff03ae32ee> in <cell line: 1>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# NameError: name 'train_test_split' is not defined
